# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = 7, 4.5
plt.rcParams["font.size"]      = 14

# %%
import matplotlib

# Set Palatino as the serif font
matplotlib.rcParams['font.family'] = 'serif'
matplotlib.rcParams['font.serif']  = 'Palatino'

# %%
fav_col = '#418094'

# %%
wavelengths = np.array([154.83614163614200, 156.14310134310100, 157.66788766788800, 160.4996336996340, 158.97484737484700,
                        160.4996336996340, 160.93528693528700, 161.37094017094000, 161.8065934065930, 162.24224664224700,
                        164.4205128205130, 164.4205128205130, 162.67789987790000, 163.1135531135530, 163.54920634920600,
                        164.85616605616600, 165.2918192918190, 165.72747252747300, 166.16312576312600, 166.59877899877900,
                        167.03443223443200, 167.47008547008500, 170.08400488400500, 169.56122100122100, 167.9057387057390,
                        168.34139194139200, 175.74749694749700, 179.45054945054900, 182.06446886446900, 183.8070818070820,
                        186.56621896621900, 188.38144078144100, 194.91623931623900, 199.27277167277200, 204.93626373626400,
                        208.42148962149000, 219.62034044387000, 224.44384751051400, 228.8971916971920, 233.03589743589700,
                        236.73894993895000, 240.7566408899740, 245.88766788766800, 250.67985347985300, 255.47203907203900,
                        260.35757892900700, 265.05641025641000, 269.8485958485960, 274.64078144078100, 279.52632129775000,
                        283.25703432370100, 287.7103785103790, 292.50256410256400, 297.29474969475000, 301.8379905808480,
                        301.21562881562900, 306.8791208791210, 311.6713064713060, 316.463492063492, 321.2556776556780,
                        321.31791383219900, 326.04786324786300, 330.8400488400490, 335.6322344322340, 340.8237688237690,
                        341.29572649572600, 345.0350834350830, 350.00879120879100, 354.80097680097700, 359.672372072372,
                        361.5536019536020, 362.642735042735, 373.5340659340660, 378.50777370777400, 383.11843711843700,
                        387.0393162393160, 394.4454212454210, 399.64421652421600, 212.85714285714300, 172.28571428571400])

qe_values = np.array([0.011791823046435600, 0.02245876304916890, 0.034643690667675900, 0.05600531253175780, 0.04535165736272750,
                      0.07366007506228910, 0.08842968429684300, 0.10270697322357800, 0.11747658245813200, 0.13196486580250400,
                      0.198733745362145, 0.18839805791220300, 0.14713888100419500, 0.16050537736146600, 0.17384725770334600,
                      0.21544832371400600, 0.22824865171728600, 0.24055665941274800, 0.253356987416028, 0.26615731541930800,
                      0.2784653231147700, 0.29126565111805000, 0.35544951358604500, 0.33833147254549500, 0.3034329958684200,
                      0.31617705869366400, 0.37989804264343000, 0.3897050966663510, 0.4013659082904930, 0.3857794283071040,
                      0.3698259059513670, 0.3589186667507700, 0.3419746428233510, 0.3262203929731610, 0.3077127962162810,
                      0.2899527969638670, 0.27985733465177800, 0.28333382393653000, 0.2869242811309230, 0.2940964928880060,
                      0.30532413101908800, 0.3167496089775710, 0.32053633123743800, 0.32380354782568800, 0.32698125163069800,
                      0.32756255190757000, 0.33221774945022200, 0.33427654346473500, 0.3362458246960090, 0.3393196297347590,
                      0.343241911763847, 0.34703211507639600, 0.3528056895953580, 0.3585792641143200, 0.360594900179771,
                      0.372498501908096, 0.3613541603947510, 0.35983244307967600, 0.3585345077227000, 0.3613467009961480,
                      0.34591320528589900, 0.3603695197791140, 0.36354722358412400, 0.36672492738913400, 0.36854626388144200,
                      0.38136026744882800, 0.3665906582142750, 0.3628758777098260, 0.35848975133108000, 0.35580436783388800,
                      0.3419746428233510, 0.3536262234417220, 0.34157183529877300, 0.3385284006686220, 0.33324714645747900,
                      0.33437884378843800, 0.3357087479965710, 0.33581516874997800, 0.2792435424354240, 0.3651291512915130])


wavelengths2 = np.array([153.66620111731842, 160.12569832402232, 164.8393854748603, 170.07681564245812, 174.96508379888266,
                         182.12290502793292, 187.7094972067039, 204.81843575418998, 214.76955307262568, 220.00698324022346,
                         230.3072625698324, 239.56005586592175, 260.16061452513964, 280.06284916201116, 300.13966480446925,
                         320.0418994413408, 339.94413407821224, 360.0209497206704, 380.27234636871503, 399.8254189944134])


qe_values2 = np.array([0.0005920452269135637, 0.05635864363773954, 0.2001758329809255, 0.3503666896659174, 0.37864575218678365,
                       0.4041323532684903, 0.3630875937590421, 0.3021041532195242, 0.2738014422755904, 0.2857452870083911,
                       0.2861272785951168, 0.31559460482093976, 0.3307012174764629, 0.3398328473814241, 0.363705234926217,
                       0.35769742260010245, 0.3704147098755815, 0.3528528344721672, 0.335290680852011, 0.3360563333259143])

# %%
plt.plot(wavelengths[:-2], qe_values[:-2])
plt.plot(wavelengths2    , qe_values2    )
plt.xlabel('Wavelength (nm)')
plt.ylabel('QE')
plt.show()

# %%
plt.plot(wavelengths2, qe_values2, color=fav_col)
plt.title('PMT quantum efficiency')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Quantum efficiency')
plt.grid(True, ls='--')
plt.show()

# %%
plt.plot(wavelengths2, qe_values2, color=fav_col, label='PMT QE')
plt.axvline(128, color='salmon', label='Ar scint. light emission')
plt.axvline(175, color='grey',   label='Xe scint. light emission', alpha=0.7)
plt.title('PMT quantum efficiency')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Quantum efficiency')
plt.grid(True, ls='--', lw=0.6)
plt.legend()
#plt.savefig(f'/Users/romoluque_c/Repositories/BACON_romo/analysis_documentation_run3/images/pmt_QE.pdf', bbox_inches='tight')
plt.show()
